# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# File for data file
file_path = "~/Documents/BedTracks/git_test/Crime_Data_from_2020_to_Present.csv"

# %%
# Reading .csv file
dataframe = pd.DataFrame(pd.read_csv(file_path))
# Formatting date-time columns
dataframe["Date Rptd"] = pd.to_datetime(dataframe["Date Rptd"], format='%m/%d/%Y %H:%M:%S %p')
dataframe["DATE OCC"] = pd.to_datetime(dataframe["Date Rptd"])

# %%
# Showing top rows 
pd.set_option("display.max_columns", len(dataframe))
pd.set_option("display.max_rows", 4)
dataframe
# Out:
#             DR_NO           Date Rptd            DATE OCC  TIME OCC  AREA  \
# 0        10304468 2020-01-08 12:00:00 2020-01-08 12:00:00      2230     3
# 1       190101086 2020-01-02 12:00:00 2020-01-02 12:00:00       330     1
# ...           ...                 ...                 ...       ...   ...
# 752909  231210064 2023-04-12 12:00:00 2023-04-12 12:00:00      1630    12
# 752910  230906458 2023-03-05 12:00:00 2023-03-05 12:00:00       900     9
#
#           AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0         Southwest          377         2     624
# 1           Central          163         2     624
# ...             ...          ...       ...     ...
# 752909  77th Street         1239         1     230
# 752910     Van Nuys          914         2     745
#
#                                            Crm Cd Desc              Mocodes  \
# 0                             BATTERY - SIMPLE ASSAULT            0444 0913
# ...

# %%
# Reseting viz options
pd.reset_option("display.max_columns")
pd.reset_option("display.max_rows")

# %%
# Top locations where crimes took place and total # of crimes
pd.DataFrame(dataframe["Premis Desc"].value_counts()).head(10)
# Out:
#                                               Premis Desc
# STREET                                             189365
# SINGLE FAMILY DWELLING                             127887
# MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)        92606
# PARKING LOT                                         53362
# OTHER BUSINESS                                      35108
# SIDEWALK                                            32553
# VEHICLE, PASSENGER/TRUCK                            22605
# GARAGE/CARPORT                                      15229
# DRIVEWAY                                            12624
# RESTAURANT/FAST FOOD                                 9565

# %%
# Weapons used, total # of crimes, and percentage from total crimes
weapons = pd.DataFrame(dataframe["Weapon Desc"].value_counts())
weapons = weapons.reset_index().rename(columns={"index":"Weapon","Weapon Desc":"Number of Crimes"})
weapons["Percentage"] = pd.Series(map(lambda x: np.round((x/sum(weapons["Number of Crimes"]))*100,2), 
                                      weapons["Number of Crimes"]))

# %%
weapons.head(10)
# Out:
#                                            Weapon  Number of Crimes  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)            140485
# 1                     UNKNOWN WEAPON/OTHER WEAPON             27112
# 2                                   VERBAL THREAT             19302
# 3                                        HAND GUN             16205
# 4                           SEMI-AUTOMATIC PISTOL              5968
# 5                KNIFE WITH BLADE 6INCHES OR LESS              5458
# 6                                 UNKNOWN FIREARM              5325
# 7                                     OTHER KNIFE              4730
# 8                               MACE/PEPPER SPRAY              2905
# 9                                         VEHICLE              2647
#
#    Percentage
# 0       53.73
# 1       10.37
# 2        7.38
# 3        6.20
# 4        2.28
# 5        2.09
# 6        2.04
# 7        1.81
# 8        1.11
# 9        1.01
